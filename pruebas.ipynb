# %%
import numpy as np
import pandas as pd

# %%
#mostrar servicios
servicios_df =  pd.read_csv('LISTADO DE SERVICIOS.csv', encoding = 'unicode_escape', sep=',')
servicios_df
# Out:
#                                            TRATAMIENTO         VALOR
# 0                  ACTIVADOR DE ANDRESSEN SIN TORNILLO      $430.500
# 1                     ACTIVADOR DE KLAMMT CON TORNILLO      $483.000
# 2                     ACTIVADOR DE KLAMMT SIN TORNILLO      $430.500
# 3                                  ACTIVADOR DE SANDER      $519.750
# 4                       ACTIVADOR DE TEUSCHER O ZURICH      $415.450
# 5                     ALARGAMIENTO CORONAL (POR PIEZA)      $175.000
# 6                       APEXIFICACION MTA X 3 SESIONES      $527.880
# 7                                          APICECTOMIA      $445.200
# 8                                         ARCO LINGUAL      $227.900
# 9                              ARCO LINGUAL CON BANDAS      $265.000
# 10                     ATACHES DE PRECISION POR UNIDAD      $291.500
# 11                                Análogo del implante       $66.959
# 12                      BARRA TRANSPALATINA CON BANDAS      $265.000
# ...
