# %%
import numpy as np
import pandas as pd

#Carga de datos
progNueva = pd.read_csv('progNueva.csv')
progTotal = pd.read_csv('progTotal.csv')
prod_df = pd.read_csv('prodPrueba.csv', engine='python')

#prog = pd.read_csv('progNueva.csv')
progNueva['fechaVenta'] = pd.to_datetime(progNueva['fechaVenta'])
progTotal['fechaVenta'] = pd.to_datetime(progTotal['fechaVenta'])

progNueva['fechaProg'] = progNueva['fechaVenta'] + pd.to_timedelta((progNueva['Semana_prog']-1), unit='w')
progTotal = progTotal.append(progNueva)

progTotal = progTotal.groupby(['Nombre_Clinica','Paciente','dni','ttmto_homol','fechaVenta'], as_index = False).sum()
progTotal['PQR'] = 0

print("Suma de Programaciones:")
progTotal
#debemos mantener las fechaVenta iguales para los mismos tratamientos para que se agrupen con el groupby. Escoger una (min?)
#->ojo: es importante, pq afecta la programacion de prod!
# Out:
# Suma de Programaciones:
#           Nombre_Clinica     Paciente  dni                      ttmto_homol  \
# 0  Autopista 104A Bogota  EVELYN DAZA  111  MENSUALIDAD ORTODONCIA METALICA
# 1  Autopista 104A Bogota  EVELYN DAZA  111  MENSUALIDAD ORTODONCIA METALICA
# 2  Autopista 104A Bogota  EVELYN DAZA  111                  RETENEDOR ESSIX
# 3  Autopista 104A Bogota  EVELYN DAZA  111                   RETENEDOR FIJO
# 4  Autopista 104A Bogota  EVELYN DAZA  111           RETIRO BRACKETS ARCADA
# 5  Autopista 104A Bogota  PEDRO GOMEZ  222            DETARTRAJE POR ARCADA
# 6  Autopista 104A Bogota  PEDRO GOMEZ  222                       PROFILAXIS
#
#   fechaVenta  Cant_pend  Cant_prod  Cantidad  Semana_prog  PQR
# 0 2018-01-02          9          0         9            6    0
# 1 2019-01-02          9          0         9            0    0
# 2 2018-01-02          2          0         2           36    0
# 3 2018-01-02          4          0         4           36    0
# 4 2018-01-02          4          0         4            1    0
# 5 2018-01-03          4          0         4            1    0
# 6 2018-01-03          4          0         4            1    0

# %%
#limpieza de archivo de produccion:
prod_df = prod_df.dropna()

# Recorte de Fecha de prod
prod_df['Fecha Cita'] = prod_df['Fecha Cita'].str[0:10]

# Columna de fecha a formato fecha:
temp_series = pd.Series()

temp_series = prod_df['Fecha Cita']
prod_df['Fecha Cita'] = pd.to_datetime(temp_series)
prod_df.head(3)
# Out:
#                  Clínica Fecha Cita  Fecha Pago    DNI  \
# 0  Autopista 104A Bogota 2016-02-01  02/01/2016  111.0
# 1  Autopista 104A Bogota 2016-02-01  02/01/2016  111.0
# 2  Autopista 104A Bogota 2016-02-01  02/01/2016  111.0
#
#                            Doctor     Paciente  Nº Historia  Presupuesto  \
# 0     MARIA ISABEL MUÑOZ QUINTERO  EVELYN DAZA        123.0         10.0
# 1  LAURA CRISTINA MOJICA CARDENAS  EVELYN DAZA        123.0          5.0
# 2  LAURA CRISTINA MOJICA CARDENAS  EVELYN DAZA        123.0          5.0
#
#                                       Tratamiento    Categoría  \
# 0  1x RETIRO BRACKETS ARCADA INFERIOR.  Pieza: 11  Generalista
# 1  1x MENSUALIDAD ORTODONCIA METALICA.  Pieza: 11  Generalista
# 2  1x MENSUALIDAD ORTODONCIA METALICA.  Pieza: 11  Generalista
#
#          Especialidad  Duración  Importe Tratamiento % Descuento  \
# 0  OPERATORIA GENERAL      30.0              90000.0          0%
# 1          PREVENCION      30.0              70000.0         10%
# 2          PREVENCION      30.0              70000.0         10%
#
#    Importe Descuento  Importe Producido  Equivalencia
# 0                0.0            90000.0           0.0
# 1             7000.0            63000.0           0.0
# 2             7000.0            63000.0           0.0

# %%
#homologacion de PRODUCCION

prod_df['temp'] = prod_df['Tratamiento'].str.contains('MENSUALIDAD ORTODONCIA METALICA')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'MENSUALIDAD ORTODONCIA METALICA'

prod_df['temp'] = prod_df['Tratamiento'].str.contains('RETIRO BRACKETS ARCADA')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'RETIRO BRACKETS ARCADA'

prod_df['temp'] = prod_df['Tratamiento'].str.contains('RETIRO BRACKETS ARCADA')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'RETIRO BRACKETS ARCADA'

prod_df['temp'] = prod_df['Tratamiento'].str.contains('PROFILAXIS')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'PROFILAXIS'

prod_df['temp'] = prod_df['Tratamiento'].str.contains('DETARTRAJE')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'DETARTRAJE POR ARCADA'

prod_df['temp'] = prod_df['Tratamiento'].str.contains('ESSIX')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'RETENEDOR ESSIX'

#print(prod_df.dtypes)

# %%
prod_df['Cant'] = (prod_df['Importe Producido'] + prod_df['Importe Descuento'])/prod_df['Importe Tratamiento']
prodResumen = prod_df.groupby(['Clínica','Paciente','DNI','ttmto_homol'], as_index = False).sum()
prodResumen = prodResumen.rename(index=str, columns={"Clínica": "Nombre_Clinica"})
prodResumen
# Out:
#           Nombre_Clinica     Paciente    DNI                      ttmto_homol  \
# 0  Autopista 104A Bogota  EVELYN DAZA  111.0  MENSUALIDAD ORTODONCIA METALICA
# 1  Autopista 104A Bogota  EVELYN DAZA  111.0           RETIRO BRACKETS ARCADA
# 2  Autopista 104A Bogota  PEDRO GOMEZ  222.0            DETARTRAJE POR ARCADA
# 3  Autopista 104A Bogota  PEDRO GOMEZ  222.0                       PROFILAXIS
#
#    Nº Historia  Presupuesto  Duración  Importe Tratamiento  Importe Descuento  \
# 0        492.0         20.0     120.0             280000.0            28000.0
# 1        123.0         10.0      30.0              90000.0                0.0
# 2        123.0          5.0      30.0              70000.0             7000.0
# 3        369.0         15.0      90.0             210000.0            21000.0
#
#    Importe Producido  Equivalencia   temp  Cant
# 0           252000.0           0.0  False   4.0
# 1            90000.0           0.0  False   1.0
# 2            63000.0           0.0  False   1.0
# 3           189000.0           0.0  False   3.0

# %%
# CONCIDENCIAS ENTRE VENTAS Y PROD
inner_df = pd.merge(progTotal, prodResumen, how='inner', left_on=['Nombre_Clinica','Paciente','dni','ttmto_homol'], right_on=['Nombre_Clinica','Paciente','DNI','ttmto_homol'])

# ACTUALIZACION DE CANTIDADES PENDIENTES
inner_df['Cant_Pend'] = inner_df['Cantidad'] - inner_df['Cant']

inner_df = inner_df[['Nombre_Clinica','Paciente','dni','ttmto_homol','Cant_Pend','Semana_prog']] #el tel del paciente no está en los DFs. Solicitar

# ACTUALIZACION DE PROGRAMACION DE ORTODONCIA METALICA
boolMask = inner_df['ttmto_homol']=='MENSUALIDAD ORTODONCIA METALICA'
#inner_df.loc[boolMask]['Cant_Pend']-1
inner_df.loc[boolMask,'Semana_prog'] = inner_df.loc[boolMask,'Semana_prog']+4 #aqui no es asi: [semana_produccion] +4
inner_df
# Out:
#           Nombre_Clinica     Paciente  dni                      ttmto_homol  \
# 0  Autopista 104A Bogota  EVELYN DAZA  111  MENSUALIDAD ORTODONCIA METALICA
# 1  Autopista 104A Bogota  EVELYN DAZA  111           RETIRO BRACKETS ARCADA
# 2  Autopista 104A Bogota  PEDRO GOMEZ  222            DETARTRAJE POR ARCADA
# 3  Autopista 104A Bogota  PEDRO GOMEZ  222                       PROFILAXIS
#
#    Cant_Pend  Semana_prog
# 0        5.0           10
# 1        1.0            1
# 2        1.0            1
# 3       -1.0            1

# %%
# extraer procedimientos de VENTAS que no cruzaron con PROD
df1 = pd.merge(progTotal, prodResumen, how='left', left_on=['Nombre_Clinica','dni','ttmto_homol'], right_on=['Nombre_Clinica','DNI','ttmto_homol'])
df1 = df1[df1['Cant'].isnull()] #probar con la func isnan()
df1
# Out:
#           Nombre_Clinica   Paciente_x  dni      ttmto_homol  Cantidad  \
# 1  Autopista 104A Bogota  EVELYN DAZA  111  RETENEDOR ESSIX         2
# 2  Autopista 104A Bogota  EVELYN DAZA  111   RETENEDOR FIJO         4
#
#    Cant_prod  Cant_pend  Semana_prog Paciente_y  DNI  Nº Historia  \
# 1          0          2           36        NaN  NaN          NaN
# 2          0          4           36        NaN  NaN          NaN
#
#    Presupuesto  Duración  Importe Tratamiento  Importe Descuento  \
# 1          NaN       NaN                  NaN                NaN
# 2          NaN       NaN                  NaN                NaN
#
#    Importe Producido  Equivalencia temp  Cant
# 1                NaN           NaN  NaN   NaN
# 2                NaN           NaN  NaN   NaN

# %%
#acomodar procedimientos que no cruzaron de la misma manera
df1 = df1.rename(index=str, columns={"Cantidad": "Cant_Pend"})
df1 = df1[['Nombre_Clinica','Paciente_x','dni','ttmto_homol','Cant_Pend','Semana_prog']]
df1 = df1.rename(index=str, columns={"Paciente_x": "Paciente"})
df1
# Out:
#           Nombre_Clinica     Paciente  dni      ttmto_homol  Cant_Pend  \
# 1  Autopista 104A Bogota  EVELYN DAZA  111  RETENEDOR ESSIX          2
# 2  Autopista 104A Bogota  EVELYN DAZA  111   RETENEDOR FIJO          4
#
#    Semana_prog
# 1           36
# 2           36

# %%
#concatenar los procedimientos que no cruzaron con los que si cruzaron (PROGRAMA DE PRODUCCION)
pd.concat([df1, inner_df], ignore_index=True)
# Out:
#           Nombre_Clinica     Paciente  dni                      ttmto_homol  \
# 0  Autopista 104A Bogota  EVELYN DAZA  111                  RETENEDOR ESSIX
# 1  Autopista 104A Bogota  EVELYN DAZA  111                   RETENEDOR FIJO
# 2  Autopista 104A Bogota  EVELYN DAZA  111  MENSUALIDAD ORTODONCIA METALICA
# 3  Autopista 104A Bogota  EVELYN DAZA  111           RETIRO BRACKETS ARCADA
# 4  Autopista 104A Bogota  PEDRO GOMEZ  222            DETARTRAJE POR ARCADA
# 5  Autopista 104A Bogota  PEDRO GOMEZ  222                       PROFILAXIS
#
#    Cant_Pend  Semana_prog
# 0        2.0           36
# 1        4.0           36
# 2       14.0           10
# 3        3.0            1
# 4        3.0            1
# 5        1.0            1
