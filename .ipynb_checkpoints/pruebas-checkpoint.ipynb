# %%
import numpy as np
import pandas as pd

def func1():
    print('hello')
# Out:
#             Clínica Fecha Pres. Nº Historia  \
# 0  Dentix Unicentro  30/07/2018    BG035064
#
#                          Presupuesto                Servicio  Descuento  \
# 0  Nº 5467 - Andres Steven Ariza GIL  Puntos y Revisiones.          0.0
#
#    Teléfono Paciente               Doctor         Especialidad  \
# 0       3.192985e+09  ANGELA SASTRE AMAYA  Puntos y Revisiones
#
#                  Explicado  Importe Pres.  Pagado Pres. % Pagado % Realizado  \
# 0  NATALY VASQUEZ MARTINEZ              0             0     100%      0.00 %
#
#   Producidos Pendientes Producción Próxima Cita Fecha Última Cita Prod
# 0          0                     0   31/07/2018     Sin Cita Producida

# %%
PPE_new.head(1)
# Out:
#             Clínica Fecha Pres. Nº Historia  \
# 0  Dentix Unicentro  30/07/2018    BG035064
#
#                          Presupuesto                Servicio  Descuento  \
# 0  Nº 5467 - Andres Steven Ariza GIL  Puntos y Revisiones.          0.0
#
#    Teléfono Paciente               Doctor         Especialidad  \
# 0       3.192985e+09  ANGELA SASTRE AMAYA  Puntos y Revisiones
#
#                  Explicado  Importe Pres.  Pagado Pres. % Pagado % Realizado  \
# 0  NATALY VASQUEZ MARTINEZ              0             0     100%      0.00 %
#
#   Producidos Pendientes Producción Próxima Cita Fecha Última Cita Prod
# 0          0                     0   31/07/2018     Sin Cita Producida
