# %% [markdown]
# # Parámetros del Programa

# %%
archivoVentas = 'ventasPrueba.csv'
archivoProd = 'prodPrueba.csv'

# NOTA: ESTE SCRIPT REQUIERE DE FECHAS DE PROGRAMACION PARA EL ARCHIVO DE VENTAS.
# NOTA: FALTA RIGHT JOIN PARA SACAR PROCEDIMIENTOS EFECTUADOS, PERO NO PRESUPUESTADOS

# %% [markdown]
# # Ajustes de Python

# %%
import pandas as pd
import numpy as np

from IPython.display import display
pd.options.display.max_columns = None

pd.set_option("display.max_rows",1000)

# %% [markdown]
# # Carga de Datos

# %%
venta_df = pd.read_csv(archivoVentas)
venta_df.head(1)
# Out:
#    idApunte  IdClinica         Nombre_Clinica idContacto  nombre apellidos  \
# 0  37436984       2000  Autopista 104A Bogota     826386  EVELYN      DAZA
#
#    dni                       Doctor      fechaApunte       Mes  \
# 0  111  LEIDIS MARIAN MEJIA CUENTAS  01/02/2018 8:49  February
#
#    Id_Tratamiento               Nombre_Tratamiento  Pieza  Cantidad  Precio  \
# 0           16711  MENSUALIDAD ORTODONCIA METALICA     11         6   70000
#
#    Precio_sin_descuento  Descuento_Porcentaje  Vr_descontado  \
# 0               1260000                  17.9         225540
#
#    Precio_con_descuento  TotalPagos
# 0               1034460       50000

# %%
prod_df = pd.read_csv(archivoProd, engine='python')
prod_df.head(1)
# Out:
#                  Clínica  Fecha Cita  Fecha Pago  DNI  \
# 0  Autopista 104A Bogota  02/01/2016  02/01/2016  111
#
#                         Doctor     Paciente  Nº Historia  Presupuesto  \
# 0  MARIA ISABEL MUÑOZ QUINTERO  EVELYN DAZA          123           10
#
#                                       Tratamiento    Categoría  \
# 0  1x RETIRO BRACKETS ARCADA INFERIOR.  Pieza: 11  Generalista
#
#          Especialidad  Duración  Importe Tratamiento % Descuento  \
# 0  OPERATORIA GENERAL        30                90000          0%
#
#    Importe Descuento  Importe Producido  Equivalencia
# 0                  0              90000             0

# %% [markdown]
# # Nuevas Columnas

# %%
# agregar columnas nuevas a VENTA - DataFrame principal
#venta_df['ttmto_homol']='' 
venta_df['unids_pdtes']=None
venta_df['ultima_aten']=None
venta_df['fecha_prog']=None 
venta_df['retraso']=None
venta_df['estado']=None
venta_df['nivel_retraso']=None

# agregar columnas nuevas a PRODUCCION
prod_df['ttmto_homol']=''

# %% [markdown]
# # Homologaciones

# %%
#homologacion de VENTAS

venta_df['ttmto_homol']=venta_df['Nombre_Tratamiento']

#diccionario de homologacion para VENTA y homologacion (si no esta incluida una homol, queda Nombre_Tratamiento)
di = {"RASPAJE Y PULIDO CORONAL(DETRARTAJE SUPRAGINGIVAL) X CUADRANTE": "RASPAJE_CUADRANTE", 
      "RETENEDOR FIJO 3X3 EN ALAMBRE": "RETENEDOR FIJO","RETENEDOR ESSIX O ESTETICOS": "RETENEDOR ESSIX", 
      "RETIRO BRACKETS ARCADA INFERIOR": "RETIRO BRACKETS ARCADA","RETIRO BRACKETS ARCADA SUPERIOR": "RETIRO BRACKETS ARCADA"}
venta_df['ttmto_homol'].replace(di, inplace=True)

# **uncomment to display venta_df:
#display(venta_df)

# %%
#homologacion de PRODUCCION

prod_df['temp'] = prod_df['Tratamiento'].str.contains('MENSUALIDAD ORTODONCIA METALICA')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'MENSUALIDAD ORTODONCIA METALICA'

prod_df['temp'] = prod_df['Tratamiento'].str.contains('RETIRO BRACKETS ARCADA')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'RETIRO BRACKETS ARCADA'

prod_df['temp'] = prod_df['Tratamiento'].str.contains('RETIRO BRACKETS ARCADA')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'RETIRO BRACKETS ARCADA'

prod_df['temp'] = prod_df['Tratamiento'].str.contains('PROFILAXIS')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'PROFILAXIS'

prod_df['temp'] = prod_df['Tratamiento'].str.contains('DETARTRAJE')
prod_df.loc[prod_df['temp'] == True,'ttmto_homol'] = 'DETARTRAJE POR ARCADA'

# %% [markdown]
# # Preprocesamiento

# %%
# NaN, vacíos,etc
# deshechar columnas innecesarias de ventas y produccion
prod_df = prod_df.dropna()
prod_df
# Out:
#                  Clínica  Fecha Cita  Fecha Pago  DNI  \
# 0  Autopista 104A Bogota  02/01/2016  02/01/2016  111
# 1  Autopista 104A Bogota  02/01/2016  02/01/2016  111
# 2  Autopista 104A Bogota  02/01/2016  02/01/2016  111
# 3  Autopista 104A Bogota  02/01/2016  02/01/2016  111
# 4  Autopista 104A Bogota  02/01/2016  02/01/2016  222
# 5  Autopista 104A Bogota  02/01/2016  02/01/2016  222
# 6  Autopista 104A Bogota  02/01/2016  02/01/2016  222
# 7  Autopista 104A Bogota  02/01/2016  02/01/2016  222
#
#                            Doctor     Paciente  Nº Historia  Presupuesto  \
# 0     MARIA ISABEL MUÑOZ QUINTERO  EVELYN DAZA          123           10
# 1     MARIA ISABEL MUÑOZ QUINTERO  EVELYN DAZA          123           12
# 2  LAURA CRISTINA MOJICA CARDENAS  EVELYN DAZA          123            5
# 3  LAURA CRISTINA MOJICA CARDENAS  EVELYN DAZA          123            5
# 4  LAURA CRISTINA MOJICA CARDENAS  PEDRO GOMEZ          123            5
# 5  LAURA CRISTINA MOJICA CARDENAS  PEDRO GOMEZ          123            5
# 6  LAURA CRISTINA MOJICA CARDENAS  PEDRO GOMEZ          123            5
# 7  LAURA CRISTINA MOJICA CARDENAS  PEDRO GOMEZ          123            5
#
#                                       Tratamiento    Categoría  \
# 0  1x RETIRO BRACKETS ARCADA INFERIOR.  Pieza: 11  Generalista
# 1  1x RETIRO BRACKETS ARCADA SUPERIOR.  Pieza: 11  Generalista
# 2  1x MENSUALIDAD ORTODONCIA METALICA.  Pieza: 11  Generalista
# 3  1x MENSUALIDAD ORTODONCIA METALICA.  Pieza: 11  Generalista
# 4                       1x PROFILAXIS.  Pieza: 11  Generalista
# 5                       1x PROFILAXIS.  Pieza: 11  Generalista
# 6                       1x PROFILAXIS.  Pieza: 11  Generalista
# 7                       2x DETARTRAJE.  Pieza: 11  Generalista
#
#          Especialidad  Duración  Importe Tratamiento % Descuento  \
# 0  OPERATORIA GENERAL        30                90000          0%
# 1      REHABILITACIÓN        30                90000          0%
# 2          PREVENCION        30                70000         10%
# 3          PREVENCION        30                70000         10%
# 4          PREVENCION        30                70000         10%
# 5          PREVENCION        30                70000         10%
# 6          PREVENCION        30                70000         10%
# 7          PREVENCION        30                70000         10%
#
#    Importe Descuento  Importe Producido  Equivalencia  \
# 0                  0              90000             0
# 1                  0             135000             0
# 2               7000              63000             0
# 3               7000              63000             0
# 4               7000              63000             0
# 5               7000              63000             0
# 6               7000              63000             0
# 7               7000              63000             0
#
#                        ttmto_homol   temp
# 0           RETIRO BRACKETS ARCADA  False
# 1           RETIRO BRACKETS ARCADA  False
# 2  MENSUALIDAD ORTODONCIA METALICA  False
# 3  MENSUALIDAD ORTODONCIA METALICA  False
# 4                       PROFILAXIS  False
# 5                       PROFILAXIS  False
# 6                       PROFILAXIS  False
# 7            DETARTRAJE POR ARCADA   True

# %%
# CAMBIAR FORMATO DE COLUMNA 'FECHA CITA' A DATE (SIN HORA) DE PROD
temp_series = pd.Series() 
temp_series = prod_df['Fecha Cita']
prod_df['Fecha Cita'] = pd.to_datetime(temp_series)

# concat nombre y apellido en VENTAS
venta_df['Paciente'] = venta_df['nombre'] + ' ' + venta_df['apellidos']

#venta_df.head()

# %% [markdown]
# # Resumen de tratamientos por cantidades y Fecha de Prog

# %%
# Resumen de CANTIDADES en Dataframe de VENTA
ventaResumen = venta_df.groupby(['Nombre_Clinica','Paciente','dni','ttmto_homol'], as_index = False).sum()
ventaResumen['fecha_prog'] = '' #esta fecha se llena en clinica y se va corriendo auto a medida que se evoluciona, en el cruce

# %%
# Programar fecha de procedimientos (luego se exportará a csv y se diligenciara en excel)
temp_series = pd.Series()

temp_series = ['01/03/2018','01/03/2018','01/03/2018','01/03/2018','01/03/2018','01/03/2018']
ventaResumen['fecha_prog'] = pd.to_datetime(temp_series)
ventaResumen
# Out:
#           Nombre_Clinica     Paciente  dni                      ttmto_homol  \
# 0  Autopista 104A Bogota  EVELYN DAZA  111  MENSUALIDAD ORTODONCIA METALICA
# 1  Autopista 104A Bogota  EVELYN DAZA  111                  RETENEDOR ESSIX
# 2  Autopista 104A Bogota  EVELYN DAZA  111                   RETENEDOR FIJO
# 3  Autopista 104A Bogota  EVELYN DAZA  111           RETIRO BRACKETS ARCADA
# 4  Autopista 104A Bogota  PEDRO GOMEZ  222            DETARTRAJE POR ARCADA
# 5  Autopista 104A Bogota  PEDRO GOMEZ  222                       PROFILAXIS
#
#    idApunte  IdClinica  Id_Tratamiento  Pieza  Cantidad  Precio  \
# 0  75208365       4000           33422     22         9  140000
# 1  38147242       2000           16721     11         1  150000
# 2  77091643       4000           33444     22         2  300000
# 3  76294499       4000           33447     42         2  200000
# 4  38944409       2000           16722     11         2  400000
# 5  77888818       4000           33444     22         2  800000
#
#    Precio_sin_descuento  Descuento_Porcentaje  Vr_descontado  \
# 0               2520000                  35.8         451080
# 1                150000                  17.9          26850
# 2                300000                  35.8          53700
# 3                200000                  35.8          35800
# 4                 40000                   0.0              0
# 5                 80000                   0.0              0
#
#    Precio_con_descuento  TotalPagos fecha_prog
# 0               2068920       66000 2018-01-03
# 1                123150      123150 2018-01-03
# 2                246300      123150 2018-01-03
# 3                164200      164200 2018-01-03
# 4                 40000       40000 2018-01-03
# 5                 80000       80000 2018-01-03

# %%
# Extraccion de Cantidad desde [Tratamientos] en PRODUCCION
prod_df['Cant'] = prod_df['Tratamiento'].astype(str).str[0]
prod_df = prod_df.astype({"Cant": int})
#prod_df

# %%
prodResumen = prod_df.groupby(['Clínica','Paciente','DNI','ttmto_homol'], as_index = False).sum()
prodResumen = prodResumen.rename(index=str, columns={"Clínica": "Nombre_Clinica"})
prodResumen
# Out:
#           Nombre_Clinica     Paciente  DNI                      ttmto_homol  \
# 0  Autopista 104A Bogota  EVELYN DAZA  111  MENSUALIDAD ORTODONCIA METALICA
# 1  Autopista 104A Bogota  EVELYN DAZA  111           RETIRO BRACKETS ARCADA
# 2  Autopista 104A Bogota  PEDRO GOMEZ  222            DETARTRAJE POR ARCADA
# 3  Autopista 104A Bogota  PEDRO GOMEZ  222                       PROFILAXIS
#
#    Nº Historia  Presupuesto  Duración  Importe Tratamiento  Importe Descuento  \
# 0          246           10        60               140000              14000
# 1          246           22        60               180000                  0
# 2          123            5        30                70000               7000
# 3          369           15        90               210000              21000
#
#    Importe Producido  Equivalencia   temp  Cant
# 0             126000             0  False     2
# 1             225000             0  False     2
# 2              63000             0   True     2
# 3             189000             0  False     3

# %% [markdown]
# # Cruce de VENTAS y PRODUCCION y ajuste de FECHA PROG

# %%
# CONCIDENCIAS ENTRE VENTAS Y PROD
inner_df = pd.merge(ventaResumen, prodResumen, how='inner', left_on=['Nombre_Clinica','Paciente','dni','ttmto_homol'], right_on=['Nombre_Clinica','Paciente','DNI','ttmto_homol'])
inner_df['Cant_Pend'] = inner_df['Cantidad'] - inner_df['Cant']
prog_df = inner_df[['Nombre_Clinica','Paciente','dni','ttmto_homol','Cant_Pend','fecha_prog']] #el tel del paciente no está en los DFs. Solicitar
prog_df
# Out:
#           Nombre_Clinica     Paciente  dni                      ttmto_homol  \
# 0  Autopista 104A Bogota  EVELYN DAZA  111  MENSUALIDAD ORTODONCIA METALICA
# 1  Autopista 104A Bogota  EVELYN DAZA  111           RETIRO BRACKETS ARCADA
# 2  Autopista 104A Bogota  PEDRO GOMEZ  222            DETARTRAJE POR ARCADA
# 3  Autopista 104A Bogota  PEDRO GOMEZ  222                       PROFILAXIS
#
#    Cant_Pend fecha_prog
# 0          7 2018-01-03
# 1          0 2018-01-03
# 2          0 2018-01-03
# 3         -1 2018-01-03

# %%
# Actualización de la FECHA DE PROG
#prog_df['fecha_prog'] = prog_df['fecha_prog'] + pd.DateOffset(months=1)
#prog_df
#prog_df[prog_df['ttmto_homol'] == 'MENSUALIDAD ORTODONCIA METALICA']['fecha_prog'] = prog_df[prog_df['ttmto_homol'] == 'MENSUALIDAD ORTODONCIA METALICA']['fecha_prog'] + pd.DateOffset(months=1)

# %%
# extraer procedimientos de VENTAS que no cruzaron con PROD
df1 = pd.merge(ventaResumen, prodResumen, how='left', left_on=['Nombre_Clinica','dni','ttmto_homol'], right_on=['Nombre_Clinica','DNI','ttmto_homol'])
df1 = df1[df1['Cant'].isnull()]
#df1

# %%
#acomodar procedimientos que no cruzaron de la misma manera
df1 = df1.rename(index=str, columns={"Cantidad": "Cant_Pend"})
df1 = df1[['Nombre_Clinica','Paciente_x','dni','ttmto_homol','Cant_Pend','fecha_prog']]
df1 = df1.rename(index=str, columns={"Paciente_x": "Paciente"})
df1
# Out:
#           Nombre_Clinica     Paciente  dni      ttmto_homol  Cant_Pend  \
# 1  Autopista 104A Bogota  EVELYN DAZA  111  RETENEDOR ESSIX          1
# 2  Autopista 104A Bogota  EVELYN DAZA  111   RETENEDOR FIJO          2
#
#   fecha_prog
# 1 2018-01-03
# 2 2018-01-03

# %%
#concatenar los procedimientos que no cruzaron con los que si cruzaron (PROGRAMA DE PRODUCCION)
ProdProg = pd.concat([df1, prog_df], ignore_index=True)
#ProdProg = ProdProg[['Nombre_Clinica','Paciente','dni','ttmto_homol','Cant_Pend','fecha_prog']]
#ProdProg[ProdProg['fecha_prog'] < '2018-01-04']
ProdProg
# Out:
#           Nombre_Clinica     Paciente  dni                      ttmto_homol  \
# 0  Autopista 104A Bogota  EVELYN DAZA  111                  RETENEDOR ESSIX
# 1  Autopista 104A Bogota  EVELYN DAZA  111                   RETENEDOR FIJO
# 2  Autopista 104A Bogota  EVELYN DAZA  111  MENSUALIDAD ORTODONCIA METALICA
# 3  Autopista 104A Bogota  EVELYN DAZA  111           RETIRO BRACKETS ARCADA
# 4  Autopista 104A Bogota  PEDRO GOMEZ  222            DETARTRAJE POR ARCADA
# 5  Autopista 104A Bogota  PEDRO GOMEZ  222                       PROFILAXIS
#
#    Cant_Pend fecha_prog
# 0          1 2018-01-03
# 1          2 2018-01-03
# 2          7 2018-01-03
# 3          0 2018-01-03
# 4          0 2018-01-03
# 5         -1 2018-01-03
